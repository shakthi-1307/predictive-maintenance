# %% [markdown]
# # C-MAPSS FD001 Exploration
#
# Scratch notebook. The reproducible analysis lives in `src/eda.py`
# (`python -m src.eda`), which writes to `reports/figures/`.

# %%
import sys

sys.path.insert(0, "..")

from src.data_loader import load_all

train, test, rul = load_all()

train.head()
